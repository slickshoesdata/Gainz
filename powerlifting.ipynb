# %%
import pandas as pd
import numpy

# %%
powerlift=pd.read_csv('openpowerlifting.csv')

# %%
powerlift
# Out:
#         MeetID                    Name Sex   Equipment   Age     Division  \
# 0            0        Angie Belk Terry   F       Wraps  47.0    Mst 45-49
# 1            0             Dawn Bogart   F  Single-ply  42.0    Mst 40-44
# 2            0             Dawn Bogart   F  Single-ply  42.0  Open Senior
# 3            0             Dawn Bogart   F         Raw  42.0  Open Senior
# 4            0            Destiny Dula   F         Raw  18.0   Teen 18-19
# 5            0         Courtney Norris   F       Wraps  28.0  Open Senior
# 6            0           Maureen Clary   F         Raw  60.0    Mst 60-64
# 7            0           Maureen Clary   F         Raw  60.0  Open Senior
# 8            0  Priscilla Sweat Pardue   F       Wraps  52.0        50-54
# 9            0  Priscilla Sweat Pardue   F         Raw  52.0       Senior
# 10           0            Kayce Hoover   F       Wraps  24.0       Junior
# 11           0            Cindy Meeker   F       Wraps  56.0    Mst 55-59
# ...

# %%
frame=pd.DataFrame(powerlift.groupby(['Sex','WeightClassKg'])['Wilks'].mean())

# %%
frame
# Out:
#                         Wilks
# Sex WeightClassKg
# F   100            246.486942
#     100+           261.406667
#     105            284.270000
#     110            256.572326
#     110+           317.133333
#     117.5          243.710000
#     30             135.986154
#     34             262.750000
#     35             161.186486
#     39              86.610000
#     40             181.512857
#     43             311.443614
#     44             258.001689
#     47             339.261948
#     48             291.802329
#     52             307.043975
#     53             356.594000
#     56             282.282943
#     57             318.511164
#     59             469.120000
#     60             288.573811
#     60+             97.642000
#     63             311.730690
#     66             282.580000
#     67.5           277.726893
#     67.5+          341.705000
#     70             365.532333
#     70+            335.650000
#     72             292.771278
# ...

# %%
powerlift.groupby(['Sex', 'WeightClassKg'])['TotalKg'].describe()
# Out:
#                      count        mean         std     min       25%      50%  \
# Sex WeightClassKg
# F   100              365.0  292.688082  110.981942   40.00  213.1900  303.910
#     100+               3.0  319.166667  247.567331   75.00  193.7500  312.500
#     105                4.0  341.250000  156.597946  175.00  235.0000  332.500
#     110              129.0  311.158682  130.821787   65.00  210.9200  322.050
#     110+               9.0  401.232222  118.302828  130.00  372.5000  435.000
#     117.5              7.0  302.508571  132.197560   80.01  255.1450  327.500
#     30                26.0   81.446154   28.756415   17.50   61.0000   92.500
#     34                 1.0  163.290000         NaN  163.29  163.2900  163.290
#     35                37.0   99.429730   32.602444   22.50   82.5000  102.100
#     39                 1.0   56.700000         NaN   56.70   56.7000   56.700
#     40                42.0  118.052381   53.934433   24.00   69.7500  122.500
# ...

# %%
powerlift.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389427 entries, 0 to 389426
# Data columns (total 17 columns):
# MeetID            389427 non-null int64
# Name              389427 non-null object
# Sex               389427 non-null object
# Equipment         389427 non-null object
# Age               147955 non-null float64
# Division          373483 non-null object
# BodyweightKg      386988 non-null float64
# WeightClassKg     385532 non-null object
# Squat4Kg          1245 non-null float64
# BestSquatKg       300689 non-null float64
# Bench4Kg          1972 non-null float64
# BestBenchKg       359289 non-null float64
# Deadlift4Kg       2806 non-null float64
# BestDeadliftKg    320512 non-null float64
# TotalKg           366125 non-null float64
# Place             388320 non-null object
# Wilks             365045 non-null float64
# dtypes: float64(10), int64(1), object(6)
# memory usage: 50.5+ MB

# %%
# %matplotlib inline

# %%
powerlift['allometric']=powerlift['TotalKg']*(powerlift['BodyweightKg'])**(-2/3)

# %%
powerlift
# Out:
#         MeetID                    Name Sex   Equipment   Age     Division  \
# 0            0        Angie Belk Terry   F       Wraps  47.0    Mst 45-49
# 1            0             Dawn Bogart   F  Single-ply  42.0    Mst 40-44
# 2            0             Dawn Bogart   F  Single-ply  42.0  Open Senior
# 3            0             Dawn Bogart   F         Raw  42.0  Open Senior
# 4            0            Destiny Dula   F         Raw  18.0   Teen 18-19
# 5            0         Courtney Norris   F       Wraps  28.0  Open Senior
# 6            0           Maureen Clary   F         Raw  60.0    Mst 60-64
# 7            0           Maureen Clary   F         Raw  60.0  Open Senior
# 8            0  Priscilla Sweat Pardue   F       Wraps  52.0        50-54
# 9            0  Priscilla Sweat Pardue   F         Raw  52.0       Senior
# 10           0            Kayce Hoover   F       Wraps  24.0       Junior
# 11           0            Cindy Meeker   F       Wraps  56.0    Mst 55-59
# ...

# %%
powerlift.to_csv('checkme.csv')

# %%
powerlift['Age'].describe()
# Out:
# count    147955.000000
# mean         31.670430
# std          12.903612
# min           5.000000
# 25%          22.000000
# 50%          28.000000
# 75%          39.000000
# max          95.000000
# Name: Age, dtype: float64

# %%
powerlift.groupby(['Sex'])['Age'].describe()
# Out:
#         count       mean        std  min   25%   50%   75%   max
# Sex
# F     43756.0  31.613710  12.109045  6.0  22.5  29.0  39.0  90.0
# M    104199.0  31.694249  13.223030  5.0  22.0  28.0  39.0  95.0

# %%
(43756./(104199.0+43756))*100
# Out:
# 29.573856915954178

# %%
(104199.0/(104199.0+43756))*100
# Out:
# 70.42614308404582

# %%
powerlift
# Out:
#         MeetID                    Name Sex   Equipment   Age     Division  \
# 0            0        Angie Belk Terry   F       Wraps  47.0    Mst 45-49
# 1            0             Dawn Bogart   F  Single-ply  42.0    Mst 40-44
# 2            0             Dawn Bogart   F  Single-ply  42.0  Open Senior
# 3            0             Dawn Bogart   F         Raw  42.0  Open Senior
# 4            0            Destiny Dula   F         Raw  18.0   Teen 18-19
# 5            0         Courtney Norris   F       Wraps  28.0  Open Senior
# 6            0           Maureen Clary   F         Raw  60.0    Mst 60-64
# 7            0           Maureen Clary   F         Raw  60.0  Open Senior
# 8            0  Priscilla Sweat Pardue   F       Wraps  52.0        50-54
# 9            0  Priscilla Sweat Pardue   F         Raw  52.0       Senior
# 10           0            Kayce Hoover   F       Wraps  24.0       Junior
# 11           0            Cindy Meeker   F       Wraps  56.0    Mst 55-59
# ...

# %%
result = powerlift.sort_values(['allometric'], ascending=False)


#analyzing allometric ranking

# %%
result
# Out:
#         MeetID                 Name Sex  Equipment   Age     Division  \
# 162603    5468         Shawn Frankl   M  Multi-ply   NaN          Pro
# 48796     1291        Kalle Räsänen   M  Multi-ply   NaN          NaN
# 48701     1287        Kalle Räsänen   M  Multi-ply   NaN          NaN
# 162970    5475         Shawn Frankl   M  Multi-ply  33.0     Pro Open
# 53763     1336            Dave Hoff   M  Multi-ply  25.0  Heavyweight
# 165365    5536    Michael Cartinian   M  Multi-ply   NaN          Pro
# 54294     1345          Jason Coker   M  Multi-ply   NaN       Middle
# 167370    5586          Lones Green   M  Multi-ply   NaN      Juniors
# 167300    5586          Lones Green   M  Multi-ply   NaN      Juniors
# 167335    5586          Lones Green   M  Multi-ply   NaN      Juniors
# 56255     1388          Jason Coker   M  Multi-ply   NaN     Pro Open
# 164027    5506    Michael Cartinian   M  Multi-ply   NaN          Pro
# ...

# %%
y=result[result['Equipment']==('Raw'or 'Wraps')]
y
# Out:
#         MeetID                   Name Sex Equipment   Age       Division  \
# 172682    5708           Jesse Norris   M       Raw  22.0          M-L-R
# 255506    6776           Jesse Norris   M       Raw   NaN           R-JR
# 351800    8011        Maliek Derstine   M       Raw  27.0           Open
# 61776     1456      Sergey Fedosienko   M       Raw  33.5           Open
# 158418    5338              Kevin Oak   M       Raw  30.0          M-M-R
# 157257    5292              Dan Green   M       Raw   NaN           M-MW
# 386131    8509            Ben Pollack   M       Raw  29.0           MR-O
# 345938    7925        Maliek Derstine   M       Raw  27.0           Open
# 341781    7873           Jesse Norris   M       Raw  21.0           Open
# 59753     1444      Sergey Fedosienko   M       Raw  31.5           Open
# 63354     1473      Sergey Fedosienko   M       Raw  34.5           Open
# 358672    8109        Maliek Derstine   M       Raw  28.0           Open
# ...

# %%
y.groupby(['Sex']).head(10)
# Out:
#         MeetID                Name Sex Equipment   Age      Division  \
# 172682    5708        Jesse Norris   M       Raw  22.0         M-L-R
# 255506    6776        Jesse Norris   M       Raw   NaN          R-JR
# 351800    8011     Maliek Derstine   M       Raw  27.0          Open
# 61776     1456   Sergey Fedosienko   M       Raw  33.5          Open
# 158418    5338           Kevin Oak   M       Raw  30.0         M-M-R
# 157257    5292           Dan Green   M       Raw   NaN          M-MW
# 386131    8509         Ben Pollack   M       Raw  29.0          MR-O
# 345938    7925     Maliek Derstine   M       Raw  27.0          Open
# 341781    7873        Jesse Norris   M       Raw  21.0          Open
# 59753     1444   Sergey Fedosienko   M       Raw  31.5          Open
# 374205    8346       Susan Salazar   F       Raw  41.0          Open
# 374278    8346       Susan Salazar   F       Raw  41.0  Master 40-44
# 383248    8484     Chakera Holcomb   F       Raw  22.0          Open
# ...

# %%
#below I'm checking and exploring wilks ranking

# %%
dual = powerlift.sort_values(['Wilks'], ascending=False)
dual[dual['Equipment']==('Raw'or 'Wraps')]
# Out:
#         MeetID                   Name Sex Equipment   Age       Division  \
# 374278    8346          Susan Salazar   F       Raw  41.0   Master 40-44
# 374205    8346          Susan Salazar   F       Raw  41.0           Open
# 238690    6495      Eric Lilliebridge   M       Raw  26.0            MOR
# 160176    5401         Stefanie Cohen   F       Raw  25.0          F-L-R
# 383248    8484        Chakera Holcomb   F       Raw  22.0           Open
# 301082    7326           Ray Williams   M       Raw  30.5            R-O
# 155933    5273         Larry Williams   M       Raw   NaN       Pro Open
# 172682    5708           Jesse Norris   M       Raw  22.0          M-L-R
# 376267    8380        Chakera Holcomb   F       Raw  22.0   Junior 20-23
# 376280    8380        Chakera Holcomb   F       Raw  22.0           Open
# 385157    8503     Marianna Gasparyan   F       Raw  26.0       Pro Open
# 63477     1473           Ray Williams   M       Raw  30.5           Open
# ...

# %%
#result[result['Equipment']==('Single-ply')]

# %%
female= (result[result['Sex']=='F'])

# %%
(female[female['Equipment']==('Raw'or 'Wraps')])
# Out:
#         MeetID                     Name Sex Equipment   Age  \
# 374205    8346            Susan Salazar   F       Raw  41.0
# 374278    8346            Susan Salazar   F       Raw  41.0
# 383248    8484          Chakera Holcomb   F       Raw  22.0
# 160176    5401           Stefanie Cohen   F       Raw  25.0
# 376267    8380          Chakera Holcomb   F       Raw  22.0
# 376280    8380          Chakera Holcomb   F       Raw  22.0
# 385157    8503       Marianna Gasparyan   F       Raw  26.0
# 371605    8307               Stacy Burr   F       Raw  25.0
# 386112    8509           Kristy Hawkins   F       Raw  35.0
# 387239    8517           Stefanie Cohen   F       Raw  25.0
# 175967    5787           Kristy Hawkins   F       Raw  35.0
# 158467    5338           Kristy Hawkins   F       Raw  36.0
# 2766        59       Marianna Gasparyan   F       Raw  25.0
# 172729    5708           Kristy Hawkins   F       Raw  35.0
# 351784    8011            Susan Salazar   F       Raw  39.0
# ...

# %%
powerlift['allometric'].isnull().sum()
# Out:
# 24382

# %%
len(powerlift['allometric'])
# Out:
# 389427

# %%
24382/389427
# Out:
# 0.0626099371640898

# %%
#about 6% NA values for allometric which means there are ~6% of NA values for totals

#this makes sense because this includes when people bomb out( miss all three attempts in at least one category), or
#get DQd for something 
#or do a deadlift only or bench only or squat(?- never seen one in practice) only meet. So they don't have a total because they only did 1 lift
